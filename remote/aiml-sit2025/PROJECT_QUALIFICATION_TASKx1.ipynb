# %% [markdown]
# <a href="https://colab.research.google.com/github/udaycodespace/AIxML-SIT2025-WebBlinders-WisdomWells/blob/main/PROJECT_QUALIFICATION_TASKx1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROJECT QUALIFICATION TASKx1 (DataFrame Manipulations)
#
# ### 🎓 Course: AI/ML SIT2025
# ### 🤝 Team: The Web Blinders × The Wisdom Wells
# ### 🧑‍💻 Submitted by: SOMAPURAM UDAY
# ### 📅 Date: 07-06-2025
#
# ---
#
# ## 🔍 Objective
#
# The goal of this project qualification assignment is to **perform various DataFrame manipulations and column-wise operations without using inbuilt shortcuts or high-level pandas utilities** like `.apply()` or `.dt`. The tasks focus on mathematical transformation, logical operations, and manual date extraction using basic Python and pandas features.

# %%
## 🚀 Dataset Used
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(10, 4),
                  index=pd.date_range('2021-07-18', periods=10),
                  columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#                    a         b         c         d
# 2021-07-18  0.439837  0.644388  0.183064 -0.984164
# 2021-07-19  0.511726  1.683123 -0.356925 -0.694169
# 2021-07-20  0.249261 -0.292406 -0.473315  0.424527
# 2021-07-21 -0.644117 -1.146836 -0.046010  0.640215
# 2021-07-22  1.407235  1.576086  0.847397  1.194217
# 2021-07-23  1.428580 -1.199066  1.157495 -0.137691
# 2021-07-24 -1.197491  0.088721 -0.823086  1.642939
# 2021-07-25  0.059346  0.836372  0.588611 -0.175214
# 2021-07-26 -0.466704 -2.106487 -0.755077 -1.659624
# 2021-07-27 -0.362460  1.173331 -0.278763  1.279642

# %% [markdown]
# 🧪 Tasks Implemented
#
# ---
#
# 1️⃣ Create a new column and store the logarithmic values for column d
#
# **Constraint:** Without using np.log() directly on Series

# %%
def log_value(x):
    return x if x <= 0 else np.log(x)

df['log_d'] = [log_value(x) for x in df['d']]

# %%
#To Show newly created column!
df
# Out:
#                    a         b         c         d     log_d
# 2021-07-18  0.439837  0.644388  0.183064 -0.984164 -0.984164
# 2021-07-19  0.511726  1.683123 -0.356925 -0.694169 -0.694169
# 2021-07-20  0.249261 -0.292406 -0.473315  0.424527 -0.856780
# 2021-07-21 -0.644117 -1.146836 -0.046010  0.640215 -0.445952
# 2021-07-22  1.407235  1.576086  0.847397  1.194217  0.177491
# 2021-07-23  1.428580 -1.199066  1.157495 -0.137691 -0.137691
# 2021-07-24 -1.197491  0.088721 -0.823086  1.642939  0.496487
# 2021-07-25  0.059346  0.836372  0.588611 -0.175214 -0.175214
# 2021-07-26 -0.466704 -2.106487 -0.755077 -1.659624 -1.659624
# 2021-07-27 -0.362460  1.173331 -0.278763  1.279642  0.246580

# %% [markdown]
# 2️⃣ Create a new column where:
#
#
# *   Negative values of column d remain same
# *   Positive values are replaced with their log values

# %%
df['transformed_d'] = [x if x < 0 else np.log(x) for x in df['d']]

# %%
df
# Out:
#                    a         b         c         d     log_d  transformed_d
# 2021-07-18  0.439837  0.644388  0.183064 -0.984164 -0.984164      -0.984164
# 2021-07-19  0.511726  1.683123 -0.356925 -0.694169 -0.694169      -0.694169
# 2021-07-20  0.249261 -0.292406 -0.473315  0.424527 -0.856780      -0.856780
# 2021-07-21 -0.644117 -1.146836 -0.046010  0.640215 -0.445952      -0.445952
# 2021-07-22  1.407235  1.576086  0.847397  1.194217  0.177491       0.177491
# 2021-07-23  1.428580 -1.199066  1.157495 -0.137691 -0.137691      -0.137691
# 2021-07-24 -1.197491  0.088721 -0.823086  1.642939  0.496487       0.496487
# 2021-07-25  0.059346  0.836372  0.588611 -0.175214 -0.175214      -0.175214
# 2021-07-26 -0.466704 -2.106487 -0.755077 -1.659624 -1.659624      -1.659624
# 2021-07-27 -0.362460  1.173331 -0.278763  1.279642  0.246580       0.246580

# %% [markdown]
# 3️⃣ Create a column from column a that returns:
#
#
# *   'yes' if the value is even (after converting to integer)
# *   'no' otherwise

# %%
df['even_a'] = ['yes' if int(x) % 2 == 0 else 'no' for x in df['a']]

# %%
df
# Out:
#                    a         b         c         d     log_d  transformed_d  \
# 2021-07-18  0.439837  0.644388  0.183064 -0.984164 -0.984164      -0.984164
# 2021-07-19  0.511726  1.683123 -0.356925 -0.694169 -0.694169      -0.694169
# 2021-07-20  0.249261 -0.292406 -0.473315  0.424527 -0.856780      -0.856780
# 2021-07-21 -0.644117 -1.146836 -0.046010  0.640215 -0.445952      -0.445952
# 2021-07-22  1.407235  1.576086  0.847397  1.194217  0.177491       0.177491
# 2021-07-23  1.428580 -1.199066  1.157495 -0.137691 -0.137691      -0.137691
# 2021-07-24 -1.197491  0.088721 -0.823086  1.642939  0.496487       0.496487
# 2021-07-25  0.059346  0.836372  0.588611 -0.175214 -0.175214      -0.175214
# 2021-07-26 -0.466704 -2.106487 -0.755077 -1.659624 -1.659624      -1.659624
# 2021-07-27 -0.362460  1.173331 -0.278763  1.279642  0.246580       0.246580
#
#            even_a
# 2021-07-18    yes
# 2021-07-19    yes
# 2021-07-20    yes
# 2021-07-21    yes
# 2021-07-22     no
# ...

# %% [markdown]
# 4️⃣ Create a new column with index values

# %%
df['index_col'] = [i for i in df.index]

# %%
df
# Out:
#                    a         b         c         d     log_d  transformed_d  \
# 2021-07-18  0.439837  0.644388  0.183064 -0.984164 -0.984164      -0.984164
# 2021-07-19  0.511726  1.683123 -0.356925 -0.694169 -0.694169      -0.694169
# 2021-07-20  0.249261 -0.292406 -0.473315  0.424527 -0.856780      -0.856780
# 2021-07-21 -0.644117 -1.146836 -0.046010  0.640215 -0.445952      -0.445952
# 2021-07-22  1.407235  1.576086  0.847397  1.194217  0.177491       0.177491
# 2021-07-23  1.428580 -1.199066  1.157495 -0.137691 -0.137691      -0.137691
# 2021-07-24 -1.197491  0.088721 -0.823086  1.642939  0.496487       0.496487
# 2021-07-25  0.059346  0.836372  0.588611 -0.175214 -0.175214      -0.175214
# 2021-07-26 -0.466704 -2.106487 -0.755077 -1.659624 -1.659624      -1.659624
# 2021-07-27 -0.362460  1.173331 -0.278763  1.279642  0.246580       0.246580
#
#            even_a  index_col
# 2021-07-18    yes 2021-07-18
# 2021-07-19    yes 2021-07-19
# 2021-07-20    yes 2021-07-20
# ...

# %% [markdown]
# 5️⃣ Split index (date) into three new columns: year, month, and day

# %%
df['year'] = [str(i).split('-')[0] for i in df.index]
df['month'] = [str(i).split('-')[1] for i in df.index]
df['day'] = [str(i).split('-')[2].split(' ')[0] for i in df.index]

# %%
df
# Out:
#                    a         b         c         d     log_d  transformed_d  \
# 2021-07-18  0.439837  0.644388  0.183064 -0.984164 -0.984164      -0.984164
# 2021-07-19  0.511726  1.683123 -0.356925 -0.694169 -0.694169      -0.694169
# 2021-07-20  0.249261 -0.292406 -0.473315  0.424527 -0.856780      -0.856780
# 2021-07-21 -0.644117 -1.146836 -0.046010  0.640215 -0.445952      -0.445952
# 2021-07-22  1.407235  1.576086  0.847397  1.194217  0.177491       0.177491
# 2021-07-23  1.428580 -1.199066  1.157495 -0.137691 -0.137691      -0.137691
# 2021-07-24 -1.197491  0.088721 -0.823086  1.642939  0.496487       0.496487
# 2021-07-25  0.059346  0.836372  0.588611 -0.175214 -0.175214      -0.175214
# 2021-07-26 -0.466704 -2.106487 -0.755077 -1.659624 -1.659624      -1.659624
# 2021-07-27 -0.362460  1.173331 -0.278763  1.279642  0.246580       0.246580
#
#            even_a  index_col  year month day
# 2021-07-18    yes 2021-07-18  2021    07  18
# ...

# %% [markdown]
# 6️⃣ Create a column that returns the weekday name of the index manually (without using .day_name())

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['weekday'] = [days[i.weekday()] for i in df.index]

# %%
df
# Out:
#                    a         b         c         d     log_d  transformed_d  \
# 2021-07-18  0.439837  0.644388  0.183064 -0.984164 -0.984164      -0.984164
# 2021-07-19  0.511726  1.683123 -0.356925 -0.694169 -0.694169      -0.694169
# 2021-07-20  0.249261 -0.292406 -0.473315  0.424527 -0.856780      -0.856780
# 2021-07-21 -0.644117 -1.146836 -0.046010  0.640215 -0.445952      -0.445952
# 2021-07-22  1.407235  1.576086  0.847397  1.194217  0.177491       0.177491
# 2021-07-23  1.428580 -1.199066  1.157495 -0.137691 -0.137691      -0.137691
# 2021-07-24 -1.197491  0.088721 -0.823086  1.642939  0.496487       0.496487
# 2021-07-25  0.059346  0.836372  0.588611 -0.175214 -0.175214      -0.175214
# 2021-07-26 -0.466704 -2.106487 -0.755077 -1.659624 -1.659624      -1.659624
# 2021-07-27 -0.362460  1.173331 -0.278763  1.279642  0.246580       0.246580
#
#            even_a  index_col  year month day    weekday
# 2021-07-18    yes 2021-07-18  2021    07  18     Sunday
# ...

# %% [markdown]
# 📌 Key Concepts Used
#
# *   List comprehension
#
#
# *   Index operations
#
# *   Date string manipulation
# *   Mathematical conditions
#
#
# *   Manual date parsing
#
#
# *   Avoided high-level pandas datetime utilities

# %% [markdown]
# Learning Outcome 🧠
#
# *   Understood how to handle and manipulate time series indexes manually.
#
# *   Practiced conditional transformation on numerical columns.
# *   Gained experience building logic without relying on pandas shortcuts.
#
#
# *   Strengthened understanding of list comprehensions and data alignment.

# %% [markdown]
# ✅ Status
#
#
# *   ✔️ Completed and tested successfully on Google Colab
# *   📁 Third Assignment Submission for AI/ML SIT2025
